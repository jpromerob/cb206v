# %% [markdown]
# ### Data Info
# 1) ATAC-seq peaks in human K562 cells.
# 2) Information on which Functional Genomic Region (FGR) the peak occurs (incl. coordinates of the FGR that you likely don't need).
# 3) Proteins localize to each peak, as identified by ChIP-seq (ENCODE databases). The value is ChIP-seq peak score. The higher the score, the more binding of the protein. "." means no binding (might be worth replacing "." with 0 or 1).

# %%
import pandas as pd
data = pd.read_csv('datasets/original_dataset.txt', sep='\t')
print(data.shape)
# Out:
# /tmp/ipykernel_249801/3824004981.py:2: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('datasets/original_dataset.txt', sep='\t')
# (114004, 460)

# %%
#@title Data Cleaning
# Drop useless columns
data.drop(['peakName', 'K562_ATACseq', 'FGRstart', 'FGRend', 'FGR', 'FGRstrand', 'peakStart', 'peakEnd'], axis=1, inplace=True)

# Replace '.' with 0 for binding scores
data.replace('.', 0, inplace=True)

# Change columns starting with 'K562_' to dtype int
for col_name in data.columns:
  if 'K562_' in col_name:
    data[col_name] = data[col_name].astype(int)

# Remove outliers by keeping only peakScore between 10 to 2000
data = data[data['peakScore'] >= 10]
data = data[data['peakScore'] <= 2000]

# Remove rows having weird values for 'FGRstrand'
# data = data[data.FGRstrand.isin(['+', '-'])]

# Remove too sparsely valued columns
# non_zero_counts = (data!=0).sum()
# data = data.loc[:, non_zero_counts > 10000]
print(data.shape)
# Out:
# (113916, 452)

# %%
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)
data.head(10).T
# Out:
#                                  0         1         2         3         4  \
# chr                           chr1      chr1      chr1      chr1      chr1
# peakScore                      928        76       673       635        92
# region                    promoter  promoter  promoter  promoter  promoter
# K562_AFF1_ENCSR241LIH           20         0        28         0         0
# K562_AFF1_ENCSR426URK            0         0         0         0         0
# ...                            ...       ...       ...       ...       ...
# K562_ZNF639_ENCSR949NVY          0         0         0         0         0
# K562_ZNF830_ENCSR033NQK          0         0         0         0         0
# K562_ZNF830_ENCSR851XLW          0         0         0         0         0
# K562_ZSCAN29_ENCSR175SZH        52         0        59         0         0
# K562_ZSCAN29_ENCSR635EXI         0         0        91        44         0
#
#                                  5         6         7         8         9
# chr                           chr1      chr1      chr1      chr1      chr1
# peakScore                      436       197       471        88       236
# region                    promoter  promoter  promoter  promoter  promoter
# K562_AFF1_ENCSR241LIH            0         0         0         0         0
# K562_AFF1_ENCSR426URK            0         0         0         0         0
# ...                            ...       ...       ...       ...       ...
# K562_ZNF639_ENCSR949NVY          0         0         0         0         0
# K562_ZNF830_ENCSR033NQK          0         0         0         0         0
# K562_ZNF830_ENCSR851XLW          0         0         0         0         0
# K562_ZSCAN29_ENCSR175SZH        86       577         0         0         0
# K562_ZSCAN29_ENCSR635EXI        59       553         0         0         0
#
# [452 rows x 10 columns]

# %%
print(data.groupby('region')['region'].count())
# Out:
# region
# CPS               1398
# TW                9145
# divergent         2452
# enhancer         10315
# geneBody         48482
# promoter         13512
# untranscribed    28612
# Name: region, dtype: int64

# %% [markdown]
# ### Task 1
#
# Regression using peakScore to predict all other proteins.

# %%
# Linear Regression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt
import numpy as np

def linear_regression(X, y):
  scaler_X = StandardScaler()
  scaler_y = StandardScaler()
  X_scaled = scaler_X.fit_transform(X)
  y_scaled = scaler_y.fit_transform(y)
  X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, random_state=42)

  model = LinearRegression()
  model.fit(X_train, y_train)
  y_pred_scaled = model.predict(X_test)
  y_pred = scaler_y.inverse_transform(y_pred_scaled)
  y_test_original = scaler_y.inverse_transform(y_test)

  mse = mean_squared_error(y_test_original, y_pred)
  r2 = r2_score(y_test_original, y_pred)

  return mse, r2

def scatter_plot(X, Y):
  X = np.array(X, dtype=np.float32)
  Y = np.array(Y, dtype=np.float32)
  plt.scatter(X, Y)
  plt.show()

df_cp = data.copy()

results = {}

for col_name in df_cp.columns[3:]:
  print(col_name)
  sub_df = df_cp[['region', 'peakScore', col_name]]
  sub_df = sub_df[(sub_df[col_name] >= 10) & (sub_df[col_name] <= 2000)]
  col_results = {}
  for region in sub_df['region'].unique():
    # print(region)
    sub_sub_df = sub_df[sub_df['region'] == region]
    num_samples = len(sub_sub_df)
    if num_samples <= 10:
      col_results[region] = {'R^2': None, 'MSE': None, 'num_samples': num_samples}
    else:
      mse, r2 = linear_regression(sub_sub_df[['peakScore']], sub_sub_df[[col_name]])
      col_results[region] = {'R^2': r2, 'MSE': mse, 'num_samples': num_samples}
  results[col_name] = col_results

  print("=================================================")
# Out:
# K562_AFF1_ENCSR241LIH
# =================================================
# K562_AFF1_ENCSR426URK
# =================================================
# K562_AGO1_ENCSR641BSL
# =================================================
# K562_ARHGAP35_ENCSR571BUF
# =================================================
# K562_ARID1B_ENCSR822CCM
# =================================================
# K562_ARID2_ENCSR491EBY
# =================================================
# K562_ARNT_ENCSR155KHM
# =================================================
# K562_ARNT_ENCSR613NUC
# =================================================
# K562_ARNT_ENCSR669NFS
# =================================================
# K562_ASH1L_ENCSR115BBC
# =================================================
# K562_ATF1_ENCSR000DNZ
# =================================================
# K562_ATF2_ENCSR869IUD
# =================================================
# K562_ATF3_ENCSR000BNU
# =================================================
# K562_ATF3_ENCSR000DOG
# =================================================
# K562_ATF3_ENCSR028UIU
# =================================================
# K562_ATF4_ENCSR145TSJ
# =================================================
# K562_ATF7_ENCSR972ZBV
# =================================================
# K562_BACH1_ENCSR000EGD
# =================================================
# K562_BCLAF1_ENCSR492LTS
# =================================================
# K562_BCLAF1_ENCSR792IYC
# =================================================
# K562_BCOR_ENCSR808AKZ
# =================================================
# K562_BDP1_ENCSR000DOK
# =================================================
# K562_BHLHE40_ENCSR000EGV
# =================================================
# K562_BMI1_ENCSR782WRO
# =================================================
# K562_BRCA1_ENCSR223MLH
# =================================================
# K562_BRD4_ENCSR583ACG
# =================================================
# K562_BRD9_ENCSR177XCS
# =================================================
# K562_BRF1_ENCSR000DOJ
# =================================================
# K562_BRF2_ENCSR000DOC
# =================================================
# K562_C11orf30_ENCSR350XWY
# =================================================
# K562_CBFA2T2_ENCSR699PVC
# =================================================
# K562_CBFA2T3_ENCSR697YLJ
# =================================================
# K562_CBX1_ENCSR948QLZ
# =================================================
# K562_CBX2_ENCSR000ATU
# =================================================
# K562_CBX3_ENCSR000ATV
# =================================================
# K562_CBX3_ENCSR000BRT
# =================================================
# K562_CBX5_ENCSR272JAT
# =================================================
# K562_CBX8_ENCSR000ATW
# =================================================
# K562_CC2D1A_ENCSR343IFJ
# =================================================
# K562_CCAR2_ENCSR598GER
# =================================================
# K562_CCNT2_ENCSR000DOA
# =================================================
# K562_CDC5L_ENCSR121PFY
# =================================================
# K562_CDK8
# =================================================
# K562_CEBPB_ENCSR000BRQ
# =================================================
# K562_CEBPB_ENCSR000EHE
# =================================================
# K562_CEBPZ_ENCSR618GDK
# =================================================
# K562_CHAMP1_ENCSR065XVO
# =================================================
# K562_CHAMP1_ENCSR315NNL
# =================================================
# K562_CHD1_ENCSR000AQD
# =================================================
# K562_CHD2_ENCSR000EHD
# =================================================
# K562_CHD4_ENCSR000ATL
# =================================================
# K562_CHD7_ENCSR000AVD
# =================================================
# K562_COPS2_ENCSR130HEG
# =================================================
# K562_CREB1_ENCSR000BSO
# =================================================
# K562_CREB3L1_ENCSR109YGM
# =================================================
# K562_CREBBP_ENCSR000ATT
# =================================================
# K562_CREM_ENCSR077DKV
# =================================================
# K562_CSDE1_ENCSR402XII
# =================================================
# K562_CSDE1_ENCSR626QJQ
# =================================================
# K562_CTBP1_ENCSR201NQZ
# =================================================
# K562_CTCFL_ENCSR000BNK
# =================================================
# K562_CTCF_ENCSR000AKO
# =================================================
# K562_CTCF_ENCSR000BPJ
# =================================================
# K562_CTCF_ENCSR000DMA
# =================================================
# K562_CTCF_ENCSR000DWE
# =================================================
# K562_CTCF_ENCSR000EGM
# =================================================
# K562_CUX1_ENCSR000EFO
# =================================================
# K562_DACH1_ENCSR030TJP
# =================================================
# K562_DDX20_ENCSR446LAV
# =================================================
# K562_DEAF1_ENCSR387SYS
# =================================================
# K562_DNMT1_ENCSR987PBI
# =================================================
# K562_DPF2_ENCSR219BXP
# =================================================
# K562_DPF2_ENCSR715CCR
# =================================================
# K562_E2F1_ENCSR563LLO
# =================================================
# K562_E2F1_ENCSR720HUL
# =================================================
# K562_E2F4_ENCSR000EWL
# =================================================
# K562_E2F6_ENCSR000BLI
# =================================================
# K562_E2F6_ENCSR000EWJ
# =================================================
# K562_E2F7_ENCSR171CAY
# =================================================
# K562_E2F8_ENCSR953DVM
# =================================================
# K562_E4F1_ENCSR731LHZ
# =================================================
# K562_EGR1_ENCSR000BNE
# =================================================
# K562_EGR1_ENCSR024CNP
# =================================================
# K562_EGR1_ENCSR211LTF
# =================================================
# K562_EHMT2_ENCSR175EOM
# =================================================
# K562_ELF1_ENCSR000BMD
# =================================================
# K562_ELF1_ENCSR502OEK
# =================================================
# K562_ELF4_ENCSR638QHV
# =================================================
# K562_ELK1_ENCSR000EFU
# =================================================
# K562_EP300_ENCSR000EGE
# =================================================
# K562_EP300_ENCSR000EGY
# =================================================
# K562_EP400_ENCSR817QKV
# =================================================
# K562_ESRRA_ENCSR486IFJ
# =================================================
# K562_ETS1_ENCSR000BKQ
# =================================================
# K562_ETV6_ENCSR000FCE
# =================================================
# K562_ETV6_ENCSR124BJR
# =================================================
# K562_EWSR1_ENCSR142YYA
# =================================================
# K562_EZH2_ENCSR000AQE
# =================================================
# K562_FIP1L1_ENCSR177DNR
# =================================================
# K562_FOSL1_ENCSR000BMV
# =================================================
# K562_FOS_ENCSR000FAI
# =================================================
# K562_FOXA1_ENCSR819LHG
# =================================================
# K562_FOXK2_ENCSR302AWT
# =================================================
# K562_FOXK2_ENCSR508DQA
# =================================================
# K562_FOXM1_ENCSR429QPP
# =================================================
# K562_FUS_ENCSR051DXE
# =================================================
# K562_GABPA_ENCSR000BLO
# =================================================
# K562_GABPB1_ENCSR138YYY
# =================================================
# K562_GATA1_ENCSR000EFT
# =================================================
# K562_GATA1_ENCSR000EWM
# =================================================
# K562_GATA2_ENCSR000BKM
# =================================================
# K562_GATA2_ENCSR000EWG
# =================================================
# K562_GATAD2A_ENCSR160QYK
# =================================================
# K562_GATAD2B_ENCSR547LKC
# =================================================
# K562_GMEB1_ENCSR928KOR
# =================================================
# K562_GTF2B_ENCSR000DOE
# =================================================
# K562_GTF2F1_ENCSR000EHC
# =================================================
# K562_GTF2F1_ENCSR189VXS
# =================================================
# K562_GTF2F1_ENCSR377BLZ
# =================================================
# K562_GTF3C2_ENCSR000DOD
# =================================================
# K562_H2AFZ_ENCSR000APC
# =================================================
# K562_H3K27ac_ENCSR000AKP
# =================================================
# K562_H3K27me3_ENCSR000AKQ
# =================================================
# K562_H3K27me3_ENCSR000DWC
# =================================================
# K562_H3K27me3_ENCSR000EWB
# =================================================
# K562_H3K36me3_ENCSR000AKR
# =================================================
# K562_H3K36me3_ENCSR000DWB
# =================================================
# K562_H3K4me1_ENCSR000AKS
# =================================================
# K562_H3K4me1_ENCSR000EWC
# =================================================
# K562_H3K4me2_ENCSR000AKT
# =================================================
# K562_H3K4me3_ENCSR000AKU
# =================================================
# K562_H3K4me3_ENCSR000DWD
# =================================================
# K562_H3K4me3_ENCSR000EWA
# =================================================
# K562_H3K4me3_ENCSR668LDD
# =================================================
# K562_H3K79me2_ENCSR000APD
# =================================================
# K562_H3K9ac_ENCSR000AKV
# =================================================
# K562_H3K9ac_ENCSR000EVZ
# =================================================
# K562_H3K9me1_ENCSR000AKW
# =================================================
# K562_H3K9me3_ENCSR000APE
# =================================================
# K562_H4K20me1_ENCSR000AKX
# =================================================
# K562_HCFC1_ENCSR000EFN
# =================================================
# K562_HDAC1_ENCSR000AQF
# =================================================
# K562_HDAC1_ENCSR387UWP
# =================================================
# K562_HDAC1_ENCSR568PGX
# =================================================
# K562_HDAC1_ENCSR711VWL
# =================================================
# K562_HDAC2_ENCSR000AQG
# =================================================
# K562_HDAC2_ENCSR000BMG
# =================================================
# K562_HDAC2_ENCSR075HTM
# =================================================
# K562_HDAC2_ENCSR893WSB
# =================================================
# K562_HDAC3_ENCSR024LKA
# =================================================
# K562_HDAC6_ENCSR000ATJ
# =================================================
# K562_HDGF_ENCSR197ALX
# =================================================
# K562_HDGF_ENCSR563YDA
# =================================================
# K562_HES1_ENCSR091JXL
# =================================================
# K562_HLTF_ENCSR090JNM
# =================================================
# K562_HMBOX1_ENCSR757IIU
# =================================================
# K562_HMGN3_ENCSR000DOB
# =================================================
# K562_HNRNPH1_ENCSR581CVA
# =================================================
# K562_HNRNPK_ENCSR014RCS
# =================================================
# K562_HNRNPLL_ENCSR112RNT
# =================================================
# K562_HNRNPL_ENCSR594BNR
# =================================================
# K562_HNRNPUL1_ENCSR296MXW
# =================================================
# K562_IKZF1_ENCSR395HWC
# =================================================
# K562_IKZF1_ENCSR948VFL
# =================================================
# K562_ILF3_ENCSR632TJQ
# =================================================
# K562_IRF2_ENCSR376WCJ
# =================================================
# K562_JUNB_ENCSR795IYP
# =================================================
# K562_JUND_ENCSR000EGN
# =================================================
# K562_JUN_ENCSR000EFS
# =================================================
# K562_JUN_ENCSR000FAH
# =================================================
# K562_KAT2B_ENCSR000ATZ
# =================================================
# K562_KAT8_ENCSR086FZL
# =================================================
# K562_KDM1A_ENCSR000ATX
# =================================================
# K562_KDM1A_ENCSR360HRA
# =================================================
# K562_KDM1A_ENCSR908CMW
# =================================================
# K562_KDM4B_ENCSR642VZY
# =================================================
# K562_KDM4B_ENCSR660RNO
# =================================================
# K562_KDM5B_ENCSR000AQA
# =================================================
# K562_KHSRP_ENCSR686EYO
# =================================================
# K562_KLF16_ENCSR760UVO
# =================================================
# K562_L3MBTL2_ENCSR530XQI
# =================================================
# K562_LARP7_ENCSR288MOZ
# =================================================
# K562_LEF1_ENCSR343ELW
# =================================================
# K562_LEF1_ENCSR832OGB
# =================================================
# K562_MAFF_ENCSR000EGI
# =================================================
# K562_MAFK_ENCSR000EGX
# =================================================
# K562_MAX_ENCSR000BLP
# =================================================
# K562_MAX_ENCSR000EFV
# =================================================
# K562_MAX_ENCSR000FAE
# =================================================
# K562_MAZ_ENCSR000EFX
# =================================================
# K562_MBD2_ENCSR221GAN
# =================================================
# K562_MCM2_ENCSR138SFL
# =================================================
# K562_MCM2_ENCSR552PSV
# =================================================
# K562_MCM3_ENCSR990AZC
# =================================================
# K562_MCM5_ENCSR079WHK
# =================================================
# K562_MCM5_ENCSR628APV
# =================================================
# K562_MCM7_ENCSR038RGL
# =================================================
# K562_MCM7_ENCSR068VRA
# =================================================
# K562_MCM7_ENCSR542WJU
# =================================================
# K562_MED1
# =================================================
# K562_MEF2A_ENCSR000BNV
# =================================================
# K562_MEIS2_ENCSR851BNE
# =================================================
# K562_MGA_ENCSR710WLO
# =================================================
# K562_MIER1_ENCSR426MDV
# =================================================
# K562_MITF_ENCSR000FCB
# =================================================
# K562_MITF_ENCSR797SWM
# =================================================
# K562_MLLT1_ENCSR107GRP
# =================================================
# K562_MLLT1_ENCSR675LRO
# =================================================
# K562_MNT_ENCSR390VGH
# =================================================
# K562_MNT_ENCSR512NLO
# =================================================
# K562_MNT_ENCSR979QYJ
# =================================================
# K562_MTA1_ENCSR807BGP
# =================================================
# K562_MTA2_ENCSR113LAS
# =================================================
# K562_MTA2_ENCSR411UYA
# =================================================
# K562_MTA3_ENCSR914NEI
# =================================================
# K562_MXI1_ENCSR000EGZ
# =================================================
# K562_MYBL2_ENCSR162IEM
# =================================================
# K562_MYC_ENCSR000DLZ
# =================================================
# K562_MYC_ENCSR000EGJ
# =================================================
# K562_MYC_ENCSR000FAG
# =================================================
# K562_MYNN_ENCSR737LTZ
# =================================================
# K562_NBN_ENCSR085QEV
# =================================================
# K562_NCOA1_ENCSR658WFQ
# =================================================
# K562_NCOA1_ENCSR711SNW
# =================================================
# K562_NCOA1_ENCSR931HNY
# =================================================
# K562_NCOA2_ENCSR349TZO
# =================================================
# K562_NCOA2_ENCSR803EKW
# =================================================
# K562_NCOA4_ENCSR119ULQ
# =================================================
# K562_NCOA6_ENCSR168CEE
# =================================================
# K562_NCOR1_ENCSR000ATY
# =================================================
# K562_NCOR1_ENCSR298JCG
# =================================================
# K562_NCOR1_ENCSR798ILC
# =================================================
# K562_NCOR1_ENCSR910JAI
# =================================================
# K562_NELFE_ENCSR000DOF
# =================================================
# K562_NEUROD1_ENCSR986CDX
# =================================================
# K562_NFATC3_ENCSR051OUX
# =================================================
# K562_NFATC3_ENCSR670FDA
# =================================================
# K562_NFE2_ENCSR000FAF
# =================================================
# K562_NFE2_ENCSR000FCC
# =================================================
# K562_NFIC_ENCSR796ITY
# =================================================
# K562_NFRKB_ENCSR657EOF
# =================================================
# K562_NFRKB_ENCSR996ESX
# =================================================
# K562_NFXL1_ENCSR085DDI
# =================================================
# K562_NFYA_ENCSR000EGR
# =================================================
# K562_NFYB_ENCSR000EGQ
# =================================================
# K562_NKRF_ENCSR331BDJ
# =================================================
# K562_NONO_ENCSR415TXN
# =================================================
# K562_NONO_ENCSR886RYH
# =================================================
# K562_NR0B1_ENCSR764YDL
# =================================================
# K562_NR2C1_ENCSR742IDN
# =================================================
# K562_NR2C2_ENCSR000EWH
# =================================================
# K562_NR2F1_ENCSR970NKQ
# =================================================
# K562_NR2F2_ENCSR000BRS
# =================================================
# K562_NR2F6_ENCSR707QWA
# =================================================
# K562_NR3C1_ENCSR325DER
# =================================================
# K562_NR3C1_ENCSR494UQJ
# =================================================
# K562_NRF1_ENCSR000EHH
# =================================================
# K562_NRF1_ENCSR494TDU
# =================================================
# K562_NRF1_ENCSR837EYC
# =================================================
# K562_NRF1_ENCSR998AJK
# =================================================
# K562_NUFIP1_ENCSR574XEO
# =================================================
# K562_PCBP1_ENCSR052PTN
# =================================================
# K562_PCBP2_ENCSR603REQ
# =================================================
# K562_PHB2_ENCSR924GXX
# =================================================
# K562_PHF20_ENCSR594SMP
# =================================================
# K562_PHF21A_ENCSR119VCX
# =================================================
# K562_PHF8_ENCSR000AQH
# =================================================
# K562_PKNOX1_ENCSR115SMW
# =================================================
# K562_PML_ENCSR000BQY
# =================================================
# K562_POLR2A_ENCSR000BMR
# =================================================
# K562_POLR2A_ENCSR000DLY
# =================================================
# K562_POLR2A_ENCSR000EHL
# =================================================
# K562_POLR2A_ENCSR000FAJ
# =================================================
# K562_POLR2A_ENCSR031TFS
# =================================================
# K562_POLR2A_ENCSR388QZF
# =================================================
# K562_POLR2AphosphoS2_ENCSR000EGF
# =================================================
# K562_POLR2AphosphoS2_ENCSR000EHF
# =================================================
# K562_POLR2AphosphoS5_ENCSR000BKR
# =================================================
# K562_POLR2B_ENCSR325RLL
# =================================================
# K562_POLR2G_ENCSR283ZRI
# =================================================
# K562_POLR3A_ENCSR000DOI
# =================================================
# K562_POLR3G_ENCSR000EHQ
# =================================================
# K562_POU5F1_ENCSR364SNE
# =================================================
# K562_PRDM10_ENCSR120MPG
# =================================================
# K562_PRPF4_ENCSR220YXI
# =================================================
# K562_PTBP1_ENCSR948KMB
# =================================================
# K562_PYGO2_ENCSR431XGJ
# =================================================
# K562_RAD21_ENCSR000BKV
# =================================================
# K562_RAD21_ENCSR000FAD
# =================================================
# K562_RAD51_ENCSR524BUE
# =================================================
# K562_RB1_ENCSR670JDQ
# =================================================
# K562_RBBP5_ENCSR000AQI
# =================================================
# K562_RBFOX2_ENCSR822LBD
# =================================================
# K562_RBM14_ENCSR423FCW
# =================================================
# K562_RBM15_ENCSR850WUE
# =================================================
# K562_RBM17_ENCSR836COE
# =================================================
# K562_RBM22_ENCSR848AOP
# =================================================
# K562_RBM25_ENCSR791OZM
# =================================================
# K562_RBM34_ENCSR899GSH
# =================================================
# K562_RBM39_ENCSR764OXF
# =================================================
# K562_RCOR1_ENCSR000EGC
# =================================================
# K562_RCOR1_ENCSR000EGG
# =================================================
# K562_REST_ENCSR000ATM
# =================================================
# K562_REST_ENCSR000BMW
# =================================================
# K562_REST_ENCSR137ZMQ
# =================================================
# K562_RFX1_ENCSR041AXL
# =================================================
# K562_RFX1_ENCSR968GIB
# =================================================
# K562_RFX5_ENCSR000EGO
# =================================================
# K562_RLF_ENCSR718SDE
# =================================================
# K562_RNF2_ENCSR000AUA
# =================================================
# K562_RNF2_ENCSR076YPO
# =================================================
# K562_RNF2_ENCSR138FUZ
# =================================================
# K562_RNF2_ENCSR608XTF
# =================================================
# K562_RNF2_ENCSR820GND
# =================================================
# K562_RUNX1_ENCSR414TYY
# =================================================
# K562_RUNX1_ENCSR588AKU
# =================================================
# K562_SAFB2_ENCSR724GSW
# =================================================
# K562_SAFB_ENCSR072VUO
# =================================================
# K562_SAP30_ENCSR000AQJ
# =================================================
# K562_SETDB1_ENCSR000AUT
# =================================================
# K562_SETDB1_ENCSR000EWD
# =================================================
# K562_SFPQ_ENCSR647PJW
# =================================================
# K562_SIN3A_ENCSR000BLR
# =================================================
# K562_SIN3A_ENCSR920BLG
# =================================================
# K562_SIN3B_ENCSR657JLK
# =================================================
# K562_SIRT6_ENCSR000AUB
# =================================================
# K562_SIRT6_ENCSR000DOH
# =================================================
# K562_SIX5_ENCSR000BGX
# =================================================
# K562_SIX5_ENCSR000BNW
# =================================================
# K562_SKIL_ENCSR336DXE
# =================================================
# K562_SMAD1_ENCSR038DJJ
# =================================================
# K562_SMAD2_ENCSR189PYJ
# =================================================
# K562_SMAD5_ENCSR000FCD
# =================================================
# K562_SMARCA4_ENCSR000EHO
# =================================================
# K562_SMARCA4_ENCSR587OQL
# =================================================
# K562_SMARCA4_ENCSR643VTW
# =================================================
# K562_SMARCA5_ENCSR895HSJ
# =================================================
# K562_SMARCB1_ENCSR000EHN
# =================================================
# K562_SMARCC2_ENCSR519WMW
# =================================================
# K562_SMARCE1_ENCSR157TCS
# =================================================
# K562_SMC3_ENCSR000EGW
# =================================================
# K562_SNIP1_ENCSR654CQU
# =================================================
# K562_SNRNP70_ENCSR754ZHU
# =================================================
# K562_SOX6_ENCSR788RSW
# =================================================
# K562_SP1_ENCSR000BKO
# =================================================
# K562_SP1_ENCSR991ELG
# =================================================
# K562_SP2_ENCSR000BNL
# =================================================
# K562_SPI1_ENCSR000BGW
# =================================================
# K562_SREBF1_ENCSR815ZDS
# =================================================
# K562_SRF_ENCSR000BLK
# =================================================
# K562_SRSF1_ENCSR832DMO
# =================================================
# K562_SRSF3_ENCSR268QIQ
# =================================================
# K562_SRSF7_ENCSR222MYK
# =================================================
# K562_SRSF9_ENCSR814AJH
# =================================================
# K562_STAT5A_ENCSR000BRR
# =================================================
# K562_SUPT5H_ENCSR894CGX
# =================================================
# K562_SUZ12_ENCSR000AUC
# =================================================
# K562_SUZ12_ENCSR412CTM
# =================================================
# K562_TAF15_ENCSR047LSJ
# =================================================
# K562_TAF1_ENCSR000BKS
# =================================================
# K562_TAF7_ENCSR000BNM
# =================================================
# K562_TAF9B_ENCSR100UQX
# =================================================
# K562_TAL1_ENCSR000EHB
# =================================================
# K562_TAL1_ENCSR106FRG
# =================================================
# K562_TARDBP_ENCSR033VAZ
# =================================================
# K562_TARDBP_ENCSR353HEP
# =================================================
# K562_TARDBP_ENCSR429XTR
# =================================================
# K562_TBL1XR1_ENCSR000EGA
# =================================================
# K562_TBL1XR1_ENCSR000EGB
# =================================================
# K562_TBP_ENCSR000EHA
# =================================================
# K562_TCF12_ENCSR189TRZ
# =================================================
# K562_TCF12_ENCSR744WOO
# =================================================
# K562_TCF7L2_ENCSR888XZK
# =================================================
# K562_TCF7_ENCSR863KUB
# =================================================
# K562_TEAD4_ENCSR000BRK
# =================================================
# K562_THAP1_ENCSR000BNN
# =================================================
# K562_THRAP3_ENCSR871TKJ
# =================================================
# K562_THRA_ENCSR264CZJ
# =================================================
# K562_TOE1_ENCSR213HBY
# =================================================
# K562_TRIM24_ENCSR907MZR
# =================================================
# K562_TRIM24_ENCSR957LDM
# =================================================
# K562_TRIM25_ENCSR213VUI
# =================================================
# K562_TRIM25_ENCSR664AOA
# =================================================
# K562_TRIM28_ENCSR000BRW
# =================================================
# K562_TRIM28_ENCSR000EVY
# =================================================
# K562_TRIM28_ENCSR474CVP
# =================================================
# K562_TRIP13_ENCSR154EIH
# =================================================
# K562_U2AF1_ENCSR690GUG
# =================================================
# K562_U2AF2_ENCSR479QAJ
# =================================================
# K562_UBTF_ENCSR000EFW
# =================================================
# K562_UBTF_ENCSR000EFZ
# =================================================
# K562_USF1_ENCSR000BKT
# =================================================
# K562_USF2_ENCSR000EHG
# =================================================
# K562_WHSC1_ENCSR000AVE
# =================================================
# K562_XRCC3_ENCSR997NGQ
# =================================================
# K562_XRCC4_ENCSR000FAC
# =================================================
# K562_XRCC5_ENCSR506KWJ
# =================================================
# K562_YBX1_ENCSR107RHZ
# =================================================
# K562_YBX3_ENCSR567JEU
# =================================================
# K562_YY1_ENCSR000BKU
# =================================================
# K562_YY1_ENCSR000BMH
# =================================================
# K562_YY1_ENCSR000EWF
# =================================================
# K562_ZBED1_ENCSR286PCG
# =================================================
# K562_ZBTB11_ENCSR331GDC
# =================================================
# K562_ZBTB2_ENCSR230PTV
# =================================================
# K562_ZBTB33_ENCSR000BKF
# =================================================
# K562_ZBTB33_ENCSR876GXA
# =================================================
# K562_ZBTB40_ENCSR237VLT
# =================================================
# K562_ZBTB5_ENCSR389PWB
# =================================================
# K562_ZBTB5_ENCSR786OQY
# =================================================
# K562_ZBTB7A_ENCSR000BME
# =================================================
# K562_ZBTB8A_ENCSR283ZNI
# =================================================
# K562_ZC3H11A_ENCSR000EFR
# =================================================
# K562_ZC3H8_ENCSR143CEO
# =================================================
# K562_ZC3H8_ENCSR494PWZ
# =================================================
# K562_ZEB2_ENCSR004GKA
# =================================================
# K562_ZEB2_ENCSR322CFO
# =================================================
# K562_ZFP36_ENCSR776CYN
# =================================================
# K562_ZFP91_ENCSR898XMH
# =================================================
# K562_ZHX1_ENCSR557RVF
# =================================================
# K562_ZKSCAN1_ENCSR882ERE
# =================================================
# K562_ZMIZ1_ENCSR000EFQ
# =================================================
# K562_ZMIZ1_ENCSR907JPB
# =================================================
# K562_ZMYM3_ENCSR102KIN
# =================================================
# K562_ZNF143_ENCSR000EGP
# =================================================
# K562_ZNF184_ENCSR546IHU
# =================================================
# K562_ZNF184_ENCSR621ATC
# =================================================
# K562_ZNF24_ENCSR099NCH
# =================================================
# K562_ZNF24_ENCSR385AHH
# =================================================
# K562_ZNF24_ENCSR695EQB
# =================================================
# K562_ZNF263_ENCSR000EWN
# =================================================
# K562_ZNF274_ENCSR000EVX
# =================================================
# K562_ZNF274_ENCSR000EWE
# =================================================
# K562_ZNF280A_ENCSR370NFS
# =================================================
# K562_ZNF282_ENCSR742TMU
# =================================================
# K562_ZNF316_ENCSR167KBO
# =================================================
# K562_ZNF316_ENCSR200JYP
# =================================================
# K562_ZNF318_ENCSR334HSW
# =================================================
# K562_ZNF318_ENCSR352BJL
# =================================================
# K562_ZNF384_ENCSR000EFP
# =================================================
# K562_ZNF407_ENCSR011NOZ
# =================================================
# K562_ZNF407_ENCSR439OCL
# =================================================
# K562_ZNF592_ENCSR249BHQ
# =================================================
# K562_ZNF639_ENCSR497VFH
# =================================================
# K562_ZNF639_ENCSR949NVY
# =================================================
# K562_ZNF830_ENCSR033NQK
# =================================================
# K562_ZNF830_ENCSR851XLW
# =================================================
# K562_ZSCAN29_ENCSR175SZH
# =================================================
# K562_ZSCAN29_ENCSR635EXI
# =================================================

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Transform the R² and MSE values into DataFrames
r2_dict = {region: {col: metrics['R^2'] for col, metrics in cols.items()} for region, cols in results.items()}
mse_dict = {region: {col: metrics['MSE'] for col, metrics in cols.items()} for region, cols in results.items()}

# Create DataFrames from the dictionaries
r2_df = pd.DataFrame(r2_dict).transpose()  # R² DataFrame
mse_df = pd.DataFrame(mse_dict).transpose()  # MSE DataFrame

# %%
# Create dictionaries for R^2, MSE, and num_samples
r2_dict = {region: {col: metrics['R^2'] for col, metrics in cols.items()} for region, cols in results.items()}
mse_dict = {region: {col: metrics['MSE'] for col, metrics in cols.items()} for region, cols in results.items()}
samples_dict = {region: {col: metrics['num_samples'] for col, metrics in cols.items()} for region, cols in results.items()}

# Create DataFrames from the dictionaries
r2_df = pd.DataFrame(r2_dict).transpose()
mse_df = pd.DataFrame(mse_dict).transpose()
samples_df = pd.DataFrame(samples_dict).transpose()

# Stack the DataFrames and convert to long format
r2_long = r2_df.stack().reset_index()
mse_long = mse_df.stack().reset_index()
samples_long = samples_df.stack().reset_index()

# Rename columns for clarity
r2_long.columns = ['region', 'protein_name', 'R^2']
mse_long.columns = ['region', 'protein_name', 'MSE']
samples_long.columns = ['region', 'protein_name', 'num_samples']

# Merge all three long-format DataFrames into a single DataFrame
combined_df = r2_long.merge(mse_long, on=['region', 'protein_name'])
combined_df = combined_df.merge(samples_long, on=['region', 'protein_name'])

# Display the combined DataFrame
display(combined_df.head(10))  # Show the top 10 rows for inspection
# Out:
#                   region   protein_name       R^2            MSE  num_samples
# 0  K562_AFF1_ENCSR241LIH       promoter  0.000875   67678.077578       2705.0
# 1  K562_AFF1_ENCSR241LIH       enhancer  0.002158   24802.590648       1320.0
# 2  K562_AFF1_ENCSR241LIH      divergent -0.021476   43750.171498        350.0
# 3  K562_AFF1_ENCSR241LIH       geneBody -0.000226   18791.120296       2593.0
# 4  K562_AFF1_ENCSR241LIH            CPS -0.279766  114779.922939         81.0
# 5  K562_AFF1_ENCSR241LIH             TW -0.006290   12241.380649        491.0
# 6  K562_AFF1_ENCSR241LIH  untranscribed  0.003117   36270.457202       1145.0
# 7  K562_AGO1_ENCSR641BSL       promoter  0.000096   38868.782297       5990.0
# 8  K562_AGO1_ENCSR641BSL       enhancer -0.005480   36060.260364       1131.0
# 9  K562_AGO1_ENCSR641BSL      divergent -0.011007   30701.081376        817.0

# %%
# Top 10 rows based on highest R^2 values
top_r2 = combined_df.sort_values(by='R^2', ascending=False).head(50)
print("Top 10 Rows by R^2:")
display(top_r2)

# # Top 10 rows based on lowest MSE values
# top_mse = combined_df.sort_values(by='MSE', ascending=True).head(10)
# print("\nTop 10 Rows by MSE:")
# print(top_mse)
# Out:
# Top 10 Rows by R^2:
#                                 region   protein_name       R^2  \
# 839           K562_HNRNPH1_ENCSR581CVA       enhancer  0.727870
# 2293           K562_ZBTB8A_ENCSR283ZNI       enhancer  0.670356
# 177              K562_CBX8_ENCSR000ATW            CPS  0.502080
# 117             K562_BRCA1_ENCSR223MLH       geneBody  0.458347
# 1129             K562_MITF_ENCSR797SWM       geneBody  0.447658
# 1516           K562_POLR2A_ENCSR031TFS       promoter  0.437488
# 2295           K562_ZBTB8A_ENCSR283ZNI  untranscribed  0.349381
# 1748             K562_RNF2_ENCSR608XTF            CPS  0.346146
# 276            K562_CREBBP_ENCSR000ATT  untranscribed  0.341220
# 1629            K562_RBM14_ENCSR423FCW            CPS  0.314181
# 2025             K562_TAL1_ENCSR106FRG       enhancer  0.312846
# 676          K562_H3K36me3_ENCSR000AKR  untranscribed  0.295977
# 115             K562_BRCA1_ENCSR223MLH       promoter  0.285541
# 1085             K562_MCM7_ENCSR068VRA  untranscribed  0.281139
# 1675            K562_RCOR1_ENCSR000EGG            CPS  0.270915
# 916               K562_JUN_ENCSR000EFS            CPS  0.268854
# 1872          K562_SMARCA4_ENCSR643VTW            CPS  0.261745
# 1298             K562_NFE2_ENCSR000FAF      divergent  0.261494
# 1074             K562_MCM5_ENCSR628APV  untranscribed  0.260945
# 1200             K562_MYNN_ENCSR737LTZ            CPS  0.260711
# 590             K562_GATA2_ENCSR000EWG            CPS  0.257891
# 777             K562_HDAC1_ENCSR387UWP            CPS  0.257649
# 1062             K562_MCM2_ENCSR552PSV             TW  0.253524
# 2217             K562_YBX3_ENCSR567JEU             TW  0.240875
# 997              K562_LEF1_ENCSR343ELW  untranscribed  0.240122
# 189             K562_CCAR2_ENCSR598GER      divergent  0.239252
# 2308            K562_ZC3H8_ENCSR143CEO             TW  0.234427
# 2215             K562_YBX3_ENCSR567JEU      divergent  0.232162
# 353             K562_DNMT1_ENCSR987PBI  untranscribed  0.228608
# 458             K562_EP300_ENCSR000EGE  untranscribed  0.209971
# 2056          K562_TBL1XR1_ENCSR000EGB             TW  0.209457
# 232            K562_CHAMP1_ENCSR065XVO             TW  0.209454
# 1874          K562_SMARCA4_ENCSR643VTW  untranscribed  0.206639
# 605           K562_GATAD2B_ENCSR547LKC             TW  0.206278
# 1871          K562_SMARCA4_ENCSR643VTW       geneBody  0.204910
# 1228            K562_NCOA1_ENCSR931HNY             TW  0.201045
# 1542  K562_POLR2AphosphoS5_ENCSR000BKR            CPS  0.200828
# 1561           K562_POLR3G_ENCSR000EHQ  untranscribed  0.199975
# 1452             K562_PHB2_ENCSR924GXX             TW  0.199679
# 2369            K562_ZNF24_ENCSR695EQB       geneBody  0.198866
# 1873          K562_SMARCA4_ENCSR643VTW             TW  0.191916
# 1895          K562_SMARCC2_ENCSR519WMW  untranscribed  0.191548
# 1902          K562_SMARCE1_ENCSR157TCS  untranscribed  0.188618
# 2389          K562_ZNF280A_ENCSR370NFS      divergent  0.187766
# 1901          K562_SMARCE1_ENCSR157TCS             TW  0.182766
# 810             K562_HDAC2_ENCSR893WSB            CPS  0.182251
# 2343            K562_ZMIZ1_ENCSR000EFQ  untranscribed  0.181634
# 577             K562_GATA1_ENCSR000EWM             TW  0.181220
# 1835             K562_SKIL_ENCSR336DXE            CPS  0.181098
# 1506           K562_POLR2A_ENCSR000EHL            CPS  0.179906
#
#                 MSE  num_samples
# 839     1828.492759         19.0
# 2293    7200.087354         15.0
# 177       56.541545         12.0
# 117     5421.135458        153.0
# 1129     514.920451         17.0
# 1516     995.106792         23.0
# 2295   34019.463967         63.0
# 1748   41396.477076        463.0
# 276   241046.968193         83.0
# 1629     396.151275         33.0
# 2025    1503.950917         12.0
# 676       90.678189         21.0
# 115    15215.717257         43.0
# 1085   36493.635789        188.0
# 1675   25054.738442        809.0
# 916    42958.148204        361.0
# 1872   27999.612868        455.0
# 1298   52125.093189         41.0
# 1074   15878.956959        515.0
# 1200    5705.694423        371.0
# 590    69779.051456        211.0
# 777    47797.150130        619.0
# 1062   12288.398393        252.0
# 2217   10874.100876         55.0
# 997    31344.450593       3797.0
# 189     1878.439696         21.0
# 2308   74551.321797        143.0
# 2215  104969.058804         53.0
# 353     4685.391606        264.0
# 458    68696.408355       5325.0
# 2056    8702.106039       1105.0
# 232    13064.453444        794.0
# 1874   23010.553437       6784.0
# 605     3216.189700        661.0
# 1871   20906.456110      16295.0
# 1228   32089.467373       1053.0
# 1542   28820.837886        599.0
# 1561   26579.089809         33.0
# 1452   58801.064349        509.0
# 2369      26.548688         26.0
# 1873   31217.323619       3078.0
# 1895   21377.072604       3845.0
# 1902   53122.452598       7554.0
# 2389    7491.791108         19.0
# 1901   61731.605876       3411.0
# 810    85682.463581        507.0
# 2343   36450.137082       1873.0
# 577    31494.844526        667.0
# 1835    5039.464512        318.0
# 1506    5024.403568        436.0
